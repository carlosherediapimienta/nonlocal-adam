# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

# %%
from functions import dL_rosenbrock_1d
import pandas as pd
from src.optimizer import AdamScratch1D, NonlocalSolverMomentumAdam
from src.utils import AdamPlotter
import matplotlib.pyplot as plt
import numpy as np
from config import *

# %% [markdown]
# # CONTINUOUS ADAM

# %%
def dL_wrapper(theta):
    return dL_rosenbrock_1d(theta, (a,))

# %%
print("Solving theta...")
optimizer_theta = NonlocalSolverMomentumAdam(
    dL=dL_wrapper,
    t_span=(lr, 10.0),
    y0=[initial_theta],
    alpha=lr,
    betas=(beta1, beta2),
    eps_base=epsilon,
    verbose=True,
    quad_order=50
)
t, y = optimizer_theta.solve()

if y.ndim == 1:
    # Equation of firs orden: y contains directly theta
    theta_history = y
    theta_dot_history = None  # No exists for first order equation
    final_state = theta_history[-1]
    print(f"\nFinal value of theta: {float(final_state):.6e}")
else:
    # Second order equation: y has columns [theta, theta_dot]
    theta_history = y[:, 0]
    theta_dot_history = y[:, 1]
    final_state = theta_history[-1]
    if isinstance(final_state, np.ndarray) and final_state.size > 1:
        print(f"\nFinal value of theta: {final_state[0]:.6e}")
        print(f"Final velocity: {final_state[1]:.6e}")
    else:
        print(f"\nFinal value of theta: {float(final_state):.6e}")

print(f"Final time: {t[-1]}")
print(f"Number of steps: {len(t)}")
# Out:
# Solving theta...
# First order equation --> using exponential kernels
# ParallelComputation: joblib backend='loky', workers=23/24
#
# ============================================================
# Building functional RHS (iteration 0)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5. 5. 5. 5. 5.]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.50s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.380e+02
# m[-1]=4.878e+02, v[-1]=2.381e+05
# Iter 0 – err 577.2006230774338
#
# ============================================================
# Building functional RHS (iteration 1)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.99964584 4.99923623 4.99880111]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.47s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.380e+02
# m[-1]=-2.012e+00, v[-1]=1.317e+02
# Iter    1 │ err=7.629714e+01 │ smooth=0.5000
#
# ============================================================
# Building functional RHS (iteration 2)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.99946876 4.99885435 4.99820167]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.48s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.380e+02
# m[-1]=-2.523e+00, v[-1]=5.513e+01
# Iter    2 │ err=5.697541e+01 │ smooth=0.5000
#
# ============================================================
# Building functional RHS (iteration 3)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.99938022 4.99866341 4.99790196]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.48s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.380e+02
# m[-1]=2.992e+00, v[-1]=5.164e+01
# Iter    3 │ err=1.085012e+01 │ smooth=0.5000
#
# ============================================================
# Building functional RHS (iteration 4)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.99933595 4.99856794 4.9977521 ]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.48s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.380e+02
# m[-1]=8.007e-01, v[-1]=5.163e+01
# Iter    4 │ err=9.241950e+00 │ smooth=0.5000
#
# ============================================================
# Building functional RHS (iteration 5)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.99931382 4.9985202  4.99767717]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.45s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.381e+02
# m[-1]=-4.933e-01, v[-1]=4.864e+01
# Iter    5 │ err=2.563033e+00 │ smooth=0.5000
#
# ============================================================
# Building functional RHS (iteration 6)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.99930275 4.99849634 4.99763971]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.51s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.381e+02
# m[-1]=-3.376e-02, v[-1]=4.778e+01
# Iter    6 │ err=1.788296e+00 │ smooth=0.5000
#
# ============================================================
# Building functional RHS (iteration 7)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.99929722 4.9984844  4.99762098]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.46s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.381e+02
# m[-1]=3.471e-01, v[-1]=4.766e+01
# Iter    7 │ err=6.996210e-01 │ smooth=0.5000
#
# ============================================================
# Building functional RHS (iteration 8)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.99929445 4.99847844 4.99761161]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.48s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.381e+02
# m[-1]=4.029e-01, v[-1]=4.771e+01
# Iter    8 │ err=2.409067e-01 │ smooth=0.5000
#
# ============================================================
# Building functional RHS (iteration 9)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.99929307 4.99847545 4.99760693]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.48s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.381e+02
# m[-1]=3.490e-01, v[-1]=4.772e+01
# Iter    9 │ err=1.520556e-01 │ smooth=0.5000
#
# ============================================================
# Building functional RHS (iteration 10)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.99929237 4.99847396 4.99760459]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.51s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.381e+02
# m[-1]=3.105e-01, v[-1]=4.771e+01
# Iter   10 │ err=7.217251e-02 │ smooth=0.5000
#
# ============================================================
# Building functional RHS (iteration 11)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.99929203 4.99847322 4.99760342]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.51s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.381e+02
# m[-1]=2.997e-01, v[-1]=4.770e+01
# Iter   11 │ err=2.561705e-02 │ smooth=0.5000
#
# ============================================================
# Building functional RHS (iteration 12)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.99929186 4.99847284 4.99760283]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.52s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.381e+02
# m[-1]=3.011e-01, v[-1]=4.769e+01
# Iter   12 │ err=1.171700e-02 │ smooth=0.5000
#
# ============================================================
# Building functional RHS (iteration 13)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.99929177 4.99847266 4.99760254]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.49s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.381e+02
# m[-1]=3.042e-01, v[-1]=4.769e+01
# Iter   13 │ err=6.909291e-03 │ smooth=0.5000
#
# ============================================================
# Building functional RHS (iteration 14)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.99929173 4.99847256 4.9976024 ]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.47s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.381e+02
# m[-1]=3.060e-01, v[-1]=4.769e+01
# Iter   14 │ err=3.332850e-03 │ smooth=0.5000
#
# ============================================================
# Building functional RHS (iteration 15)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.9992917  4.99847252 4.99760232]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.47s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.381e+02
# m[-1]=3.065e-01, v[-1]=4.769e+01
# Iter   15 │ err=1.305037e-03 │ smooth=0.5000
#
# ============================================================
# Building functional RHS (iteration 16)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.99929169 4.99847249 4.99760229]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.46s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.381e+02
# m[-1]=3.065e-01, v[-1]=4.769e+01
# Iter   16 │ err=5.340571e-04 │ smooth=0.5000
#
# ============================================================
# Building functional RHS (iteration 17)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.99929169 4.99847248 4.99760227]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.48s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.381e+02
# m[-1]=3.064e-01, v[-1]=4.769e+01
# Iter   17 │ err=2.934543e-04 │ smooth=0.5000
#
# ============================================================
# Building functional RHS (iteration 18)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.99929169 4.99847248 4.99760226]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.48s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.381e+02
# m[-1]=3.063e-01, v[-1]=4.769e+01
# Iter   18 │ err=1.607033e-04 │ smooth=0.5000
#
# ============================================================
# Building functional RHS (iteration 19)...
# ============================================================
# ¿No finitos en y?: False (NaN: False, Inf: False)
#
# --- DEBUG interpolador ---
# y_pos shape: (9999,), dtype: float64
# y_pos[:5]: [5.         5.         4.99929168 4.99847247 4.99760225]
# y_pos finitos: True
# --- FIN DEBUG ---
#
# Computing moments for 9999 time points...
#   Parallel execution: 9999 items → 23 workers (joblib/loky)
# Moments computed in 1.51s
# m[0]=0.000e+00, v[0]=0.000e+00
# m[1]=4.644e+01, v[1]=2.381e+02
# m[-1]=3.063e-01, v[-1]=4.769e+01
# Iter   19 │ err=7.500069e-05 │ smooth=0.5000
#
# ============================================================
# Convergence achieved!
# Final iteration: 19
# Final error: 7.500069e-05
# Final smoothing: 0.5000
# ============================================================
#
#
# Final value of theta: 1.029130e+00
# Final time: 9.998999999999999
# Number of steps: 9999

# %%
# Crear el plotter y visualizar
plotter = AdamPlotter(theta_history, optimizer_theta._last_m[:, 1], optimizer_theta._last_v[:, 1])

# Plotear todo
plotter.plot('all')
plt.show()

# %% [markdown]
# # Save Results

# %%
# Create DataFrame
df_continuous = pd.DataFrame({
    't': np.arange(len(theta_history)),
    'theta_history': theta_history,
    'm_history': optimizer_theta._last_m[:, 1],
    'v_history': optimizer_theta._last_v[:, 1]
})

# Save to CSV
df_continuous.to_csv(f'results_1rst_order/continuous_adam_results_lr_{lr}_beta1_{beta1}_beta2_{beta2}.csv', index=False)
print(f"Results saved in 'results_1rst_order/continuous_adam_results.csv'")
print(f"Total rows: {len(df_continuous)}")
# Out:
# Results saved in 'results_1rst_order/continuous_adam_results.csv'
# Total rows: 9999
